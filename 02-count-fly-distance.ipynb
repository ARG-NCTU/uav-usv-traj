# %%
import pandas as pd
from geopandas import GeoDataFrame, read_file

import sys
sys.path.append("..")
import movingpandas as mpd
mpd.show_versions()

import warnings
warnings.simplefilter("ignore")
# Out:
# /home/arg/miniconda3/envs/movingpandas/lib/python3.9/site-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# MovingPandas 0.17.2
#
# SYSTEM INFO
# -----------
# python     : 3.9.19 | packaged by conda-forge | (main, Mar 20 2024, 12:50:21)  [GCC 12.3.0]
# executable : /home/arg/miniconda3/envs/movingpandas/bin/python
# machine    : Linux-5.15.0-105-generic-x86_64-with-glibc2.31
#
# GEOS, GDAL, PROJ INFO
# ---------------------
# GEOS       : None
# GEOS lib   : None
# GDAL       : 3.8.4
# GDAL data dir: /home/arg/miniconda3/envs/movingpandas/share/gdal
# PROJ       : 9.3.1
# PROJ data dir: /home/arg/miniconda3/envs/movingpandas/share/proj
#
# PYTHON DEPENDENCIES
# -------------------
# geopandas  : 0.14.3
# pandas     : 2.2.1
# fiona      : 1.9.6
# numpy      : 1.26.4
# shapely    : 2.0.3
# rtree      : 1.2.0
# pyproj     : 3.6.1
# matplotlib : 3.8.3
# mapclassify: 2.6.1
# geopy      : 2.4.1
# holoviews  : 1.18.3
# hvplot     : 0.9.2
# geoviews   : 1.11.1
# stonesoup  : 1.2

# %%
import csv
import os
import shutil
import xml.etree.ElementTree as ET
from datetime import timedelta

import numpy as np
from dateutil import parser


def generate_grid_and_path(x_min, x_max, x_n, y_min, y_max, y_n):
    x_values = np.linspace(x_min, x_max, x_n)
    y_values = np.linspace(y_min, y_max, y_n)
    X, Y = np.meshgrid(x_values, y_values)
    path = []

    for i in range(x_n):
        for j in range(y_n):
            if i % 2 == 0:
                path.append((X[j, i], Y[j, i]))
            else:
                path.append((X[-j - 1, i], Y[-j - 1, i]))

    if x_n % 2 == 0:
        for j in range(y_n):
            for i in range(x_n):
                if j % 2 == 0:
                    path.append((X[j, i], Y[j, i]))
                else:
                    path.append((X[j, -i - 1], Y[j, -i - 1]))
    else:
        for j in range(y_n - 1, -1, -1):
            for i in range(x_n):
                if j % 2 == 0:
                    path.append((X[j, i], Y[j, i]))
                else:
                    path.append((X[j, -i - 1], Y[j, -i - 1]))
    return path

'''
def parse_corrdinates_str_list(kml_path):
    tree = ET.parse(kml_path)
    root = tree.getroot()
    namespace = {"kml": "http://www.opengis.net/kml/2.2"}
    specific_name = "vehicle_global_position:14"
    #namespace = {"kml"}
    #specific_name = "R8039938565"
    coordinates = None
    coordinates_str_list = []
    for placemark in root.findall(".//kml:Placemark", namespaces=namespace):
        name = placemark.find("kml:name", namespaces=namespace)
        if name is not None and name.text == specific_name:
            # Find the LineString element
            line_string = placemark.find(".//kml:LineString", namespaces=namespace)
            if line_string is not None:
                # Extract the coordinates
                coordinates = line_string.find("kml:coordinates", namespaces=namespace)
                if coordinates is not None:
                    coordinates_str_list.append(coordinates.text.strip())
    return coordinates_str_list
'''
def parse_corrdinates_str_list(kml_path):
    tree = ET.parse(kml_path)
    root = tree.getroot()
    coordinates = None
    coordinates_str_list = []
    for placemark in root.findall(".//Placemark"):
        name = placemark.find("name")
        if name is not None :
            # Find the LineString element
            line_string = placemark.find(".//LineString")
            if line_string is not None:
                # Extract the coordinates
                coordinates = line_string.find("coordinates")
                if coordinates is not None:
                    coordinates_str_list.append(coordinates.text.strip())
    return coordinates_str_list

def get_means(coordinates):
    mean_x = np.mean([coord[0] for coord in coordinates])
    mean_y = np.mean([coord[1] for coord in coordinates])
    return mean_x, mean_y


def write_to_csv(
    csv_file_path, coordinates, trajectory_id, tracker, base_timestamp, mean_x, mean_y, grid_size_half=10e-5, xy_n=10
):
    base_time = parser.parse(base_timestamp)
    with open(csv_file_path, "w", newline="") as csv_file:
        writer = csv.writer(csv_file, delimiter=";")

        headers = ["X", "Y", "fid", "id", "sequence", "trajectory_id", "tracker", "t"]
        writer.writerow(headers)
        for i, coord in enumerate(coordinates, start=1):
            x, y, _ = coord
            timestamp = (base_time + timedelta(seconds=1 * (i - 1))).isoformat()
            row = [x, y, i, i, i, trajectory_id, tracker, timestamp]
            writer.writerow(row)

        path = generate_grid_and_path(
            mean_x - grid_size_half,
            mean_x + grid_size_half,
            xy_n,
            mean_y - grid_size_half,
            mean_y + grid_size_half,
            xy_n,
        )
        for i, coord in enumerate(path, start=len(coordinates) + 1):
            x, y = coord
            timestamp = (base_time + timedelta(seconds=1 * (i - 1))).isoformat()
            row = [x, y, i, i, i, trajectory_id + 1, tracker, timestamp]
            writer.writerow(row)

    print(f"Saved to {csv_file_path}")


def convert_kml_to_csv(kml_path):
    kml_name = kml_path.split("/")[-1].split(".")[0]

    #print(parse_corrdinates_str_list(kml_path))
    coordinates_str_list = parse_corrdinates_str_list(kml_path)[0].split()
    coordinates = [[float(coord) for coord in coord_str.split(",")] for coord_str in coordinates_str_list]
    mean_x, mean_y = get_means(coordinates)
    print(f"Min x: {min([coord[0] for coord in coordinates])}, Min y: {min([coord[1] for coord in coordinates])}")
    print(f"Max x: {max([coord[0] for coord in coordinates])}, Max y: {max([coord[1] for coord in coordinates])}")
    xy_n =61
    grid_size_half = 1 / 111_111 * xy_n # Convert to meter

    print(f"Mean x: {mean_x}, Mean y: {mean_y}")

    trajectory_id = 1
    tracker = 19
    base_timestamp = "2008-12-11 04:42:14+00"

    csv_file_path = f"./data/csv/{kml_name}.csv"
    
    write_to_csv(
        csv_file_path,
        coordinates,
        trajectory_id,
        tracker,
        base_timestamp,
        mean_x,
        mean_y,
        grid_size_half,
        xy_n=xy_n,
    )
    # shutil.copy(csv_file_path, os.path.expanduser("./data/"))
    print(f"Copied to ./data/{kml_name}.csv")

def get_specific_filenames(directory, extension):
    filenames = [filename for filename in os.listdir(directory) if filename.endswith(extension)]
    return filenames


# Set the directory path and file extension
directory_path = "./data/raw_kml"
file_extension = ".kml"  

# find all kml files in the directory
kml_pathes = get_specific_filenames(directory_path, file_extension)


kml_pathes = [f"./data/raw_kml/{kml_path}" for kml_path in kml_pathes]

for kml_path in kml_pathes:
    convert_kml_to_csv(kml_path)
# Out:
# Min x: 120.40740053799719, Min y: 23.355098840108454
# Max x: 120.40780429085565, Max y: 23.355971487498795
# Mean x: 120.4076268950103, Mean y: 23.355633123400597
# Saved to ./data/csv/飛行軌跡_20230919105048_R2284074695.csv
# Copied to ./data/飛行軌跡_20230919105048_R2284074695.csv
# Min x: 120.3925153491403, Min y: 23.352835701417302
# Max x: 120.39300399227557, Max y: 23.35375661990722
# Mean x: 120.39278001241965, Mean y: 23.353421660793803
# Saved to ./data/csv/飛行軌跡_20231015065924_R8427588649.csv
# Copied to ./data/飛行軌跡_20231015065924_R8427588649.csv
# Min x: 120.3980825430755, Min y: 23.38142585387479
# Max x: 120.39831699987501, Max y: 23.382322491020076
# Mean x: 120.39826107779452, Mean y: 23.38204967911413
# Saved to ./data/csv/飛行軌跡_20230906144143_R7071630692.csv
# Copied to ./data/飛行軌跡_20230906144143_R7071630692.csv
# Min x: 120.43693902750097, Min y: 23.391749042362548
# Max x: 120.43722378531477, Max y: 23.39225536360663
# Mean x: 120.43707935632995, Mean y: 23.392012434311884
# Saved to ./data/csv/飛行軌跡_20231022091321_R7987954293.csv
# Copied to ./data/飛行軌跡_20231022091321_R7987954293.csv
# Min x: 120.41207947464306, Min y: 23.397139990169904
# Max x: 120.41237377167708, Max y: 23.398138593349355
# Mean x: 120.41222247509658, Mean y: 23.39758436225528
# Saved to ./data/csv/飛行軌跡_20230802091131_R2648751100.csv
# Copied to ./data/飛行軌跡_20230802091131_R2648751100.csv
# Min x: 120.3445550813135, Min y: 23.350306135824976
# Max x: 120.34578629842002, Max y: 23.351188781991734
# Mean x: 120.34534796802663, Mean y: 23.35093221344674
# Saved to ./data/csv/飛行軌跡_20231024080148_R3316073813.csv
# Copied to ./data/飛行軌跡_20231024080148_R3316073813.csv
# Min x: 120.44496275888498, Min y: 23.384106907485442
# Max x: 120.4462986663828, Max y: 23.385674784751746
# Mean x: 120.44575602803948, Mean y: 23.384799428442967
# Saved to ./data/csv/飛行軌跡_20230905100545_R3802799874.csv
# Copied to ./data/飛行軌跡_20230905100545_R3802799874.csv
# Min x: 120.40410429597996, Min y: 23.3637256528311
# Max x: 120.40506207581069, Max y: 23.364161016554977
# Mean x: 120.40431999838158, Mean y: 23.363956214945052
# Saved to ./data/csv/飛行軌跡_20231011114902_R1931569622.csv
# Copied to ./data/飛行軌跡_20231011114902_R1931569622.csv
# Min x: 120.41432214889134, Min y: 23.393459766087876
# Max x: 120.41488923979519, Max y: 23.39421678462671
# Mean x: 120.41468407965525, Mean y: 23.393835184404566
# Saved to ./data/csv/飛行軌跡_20230812105252_R6390526214.csv
# Copied to ./data/飛行軌跡_20230812105252_R6390526214.csv
# Min x: 120.41704895826008, Min y: 23.381729501927595
# Max x: 120.41732228603361, Max y: 23.38264486355379
# Mean x: 120.41719974138337, Mean y: 23.382287053695276
# Saved to ./data/csv/飛行軌跡_20230718154054_R5900551673.csv
# Copied to ./data/飛行軌跡_20230718154054_R5900551673.csv
# Min x: 120.40911454245389, Min y: 23.398132616047917
# Max x: 120.40922398756553, Max y: 23.39914904746044
# Mean x: 120.40917826461157, Mean y: 23.398658393653847
# Saved to ./data/csv/飛行軌跡_20230908111722_R0724138501.csv
# Copied to ./data/飛行軌跡_20230908111722_R0724138501.csv
# Min x: 120.42095635720403, Min y: 23.3995318577814
# Max x: 120.42201362695943, Max y: 23.40029134149784
# Mean x: 120.42155453801043, Mean y: 23.40005238162029
# Saved to ./data/csv/飛行軌跡_20230909071259_R8515227017.csv
# Copied to ./data/飛行軌跡_20230909071259_R8515227017.csv
# Min x: 120.4229500348656, Min y: 23.398296077150952
# Max x: 120.42393793357581, Max y: 23.39837067113663
# Mean x: 120.42325123507635, Mean y: 23.398339630051687
# Saved to ./data/csv/飛行軌跡_20230812111704_R1428837492.csv
# Copied to ./data/飛行軌跡_20230812111704_R1428837492.csv
# Min x: 120.41082206620196, Min y: 23.353156318564448
# Max x: 120.41118029781896, Max y: 23.354009020997438
# Mean x: 120.41105477277391, Mean y: 23.353481773436368
# Saved to ./data/csv/飛行軌跡_20230907141216_R0181732190.csv
# Copied to ./data/飛行軌跡_20230907141216_R0181732190.csv
# Min x: 120.41424562137814, Min y: 23.379015353007738
# Max x: 120.41434083319129, Max y: 23.379951251090997
# Mean x: 120.41428995998272, Mean y: 23.379577437614767
# Saved to ./data/csv/飛行軌跡_20230814161545_R5903730480.csv
# Copied to ./data/飛行軌跡_20230814161545_R5903730480.csv
# Min x: 120.44348126644282, Min y: 23.367025844090424
# Max x: 120.44384503768794, Max y: 23.36796353793521
# Mean x: 120.4436861980285, Mean y: 23.36764429148088
# Saved to ./data/csv/飛行軌跡_20230918143331_R2267111724.csv
# Copied to ./data/飛行軌跡_20230918143331_R2267111724.csv
# Min x: 120.38521078336908, Min y: 23.363946063935057
# Max x: 120.38546030270587, Max y: 23.364873197645807
# Mean x: 120.3853351063386, Mean y: 23.364565647036066
# Saved to ./data/csv/飛行軌跡_20230813063025_R4313918744.csv
# Copied to ./data/飛行軌跡_20230813063025_R4313918744.csv
# Min x: 120.40603778358094, Min y: 23.39833449523875
# Max x: 120.40636786472822, Max y: 23.399198501268017
# Mean x: 120.40618206671387, Mean y: 23.398820393610162
# Saved to ./data/csv/飛行軌跡_20230826095602_R7389501617.csv
# Copied to ./data/飛行軌跡_20230826095602_R7389501617.csv
# Min x: 120.4023246761792, Min y: 23.380430628658285
# Max x: 120.40348948763801, Max y: 23.381664112679033
# Mean x: 120.40285571687875, Mean y: 23.381026969484104
# Saved to ./data/csv/飛行軌跡_20231025061516_R4583702627.csv
# Copied to ./data/飛行軌跡_20231025061516_R4583702627.csv
# Min x: 120.4032000860912, Min y: 23.354076964217093
# Max x: 120.40394105106334, Max y: 23.35497359755833
# Mean x: 120.40355055483653, Mean y: 23.354563291337744
# Saved to ./data/csv/飛行軌跡_20231019170714_R6325993691.csv
# Copied to ./data/飛行軌跡_20231019170714_R6325993691.csv
# Min x: 120.34642279607739, Min y: 23.363629158288813
# Max x: 120.34663079799415, Max y: 23.364574845378847
# Mean x: 120.34654898363279, Mean y: 23.364119949150172
# Saved to ./data/csv/飛行軌跡_20230925083706_R1581829495.csv
# Copied to ./data/飛行軌跡_20230925083706_R1581829495.csv
# Min x: 120.41843826618243, Min y: 23.3730483295437
# Max x: 120.41877632433773, Max y: 23.37401431894416
# Mean x: 120.41864130438863, Mean y: 23.37348583197974
# Saved to ./data/csv/飛行軌跡_20230825111614_R0502413408.csv
# Copied to ./data/飛行軌跡_20230825111614_R0502413408.csv
# Min x: 120.44916834320671, Min y: 23.369040067757556
# Max x: 120.44960365393467, Max y: 23.369855599181314
# Mean x: 120.44935892274437, Mean y: 23.36954970270762
# Saved to ./data/csv/飛行軌跡_20230822151236_R5222911321.csv
# Copied to ./data/飛行軌跡_20230822151236_R5222911321.csv
# Min x: 120.39919097942044, Min y: 23.374703926148182
# Max x: 120.39954413649319, Max y: 23.37563170509628
# Mean x: 120.3993865721307, Mean y: 23.375110055814364
# Saved to ./data/csv/飛行軌跡_20230914153817_R0815349422.csv
# Copied to ./data/飛行軌跡_20230914153817_R0815349422.csv
# Min x: 120.4210838730349, Min y: 23.38177106667882
# Max x: 120.42167470778448, Max y: 23.382706108070263
# Mean x: 120.42138478499345, Mean y: 23.3822120668231
# Saved to ./data/csv/飛行軌跡_20230802075544_R1376117400.csv
# Copied to ./data/飛行軌跡_20230802075544_R1376117400.csv
# Min x: 120.39480870072906, Min y: 23.398375012410867
# Max x: 120.3952675359014, Max y: 23.399197863853235
# Mean x: 120.39504879188371, Mean y: 23.398622181474643
# Saved to ./data/csv/飛行軌跡_20230812130932_R6521874735.csv
# Copied to ./data/飛行軌跡_20230812130932_R6521874735.csv
# Min x: 120.39309317270806, Min y: 23.355576997558032
# Max x: 120.39335438799789, Max y: 23.355657259830245
# Mean x: 120.39318539310334, Mean y: 23.35561294577404
# Saved to ./data/csv/飛行軌跡_20230912083446_R1653803264.csv
# Copied to ./data/飛行軌跡_20230912083446_R1653803264.csv
# Min x: 120.41001906253923, Min y: 23.40280959433928
# Max x: 120.41090940884425, Max y: 23.403424718241084
# Mean x: 120.41059692063808, Mean y: 23.403070852253396
# Saved to ./data/csv/飛行軌跡_20230810110022_R4445338146.csv
# Copied to ./data/飛行軌跡_20230810110022_R4445338146.csv
# Min x: 120.42528716080643, Min y: 23.354683637347993
# Max x: 120.42588637875723, Max y: 23.354805312849106
# Mean x: 120.42548788907932, Mean y: 23.354746264412487
# Saved to ./data/csv/飛行軌跡_20231101082420_R3376458313.csv
# Copied to ./data/飛行軌跡_20231101082420_R3376458313.csv
# Min x: 120.25376414844155, Min y: 23.272175089013817
# Max x: 120.25409403508466, Max y: 23.273123366109832
# Mean x: 120.25396940325892, Mean y: 23.272458732515048
# Saved to ./data/csv/飛行軌跡_20231109120753_R6507975232.csv
# Copied to ./data/飛行軌跡_20231109120753_R6507975232.csv
# Min x: 120.42442057814802, Min y: 23.42001541906845
# Max x: 120.4246469700248, Max y: 23.4213754201229
# Mean x: 120.42454052555517, Mean y: 23.42060939463196
# Saved to ./data/csv/飛行軌跡_20230912115306_R0206765629.csv
# Copied to ./data/飛行軌跡_20230912115306_R0206765629.csv
# Min x: 120.36769297399044, Min y: 23.35395249076572
# Max x: 120.36835400104884, Max y: 23.35499229390683
# Mean x: 120.3678756391115, Mean y: 23.35437264770471
# Saved to ./data/csv/飛行軌跡_20231006124939_R6581405358.csv
# Copied to ./data/飛行軌跡_20231006124939_R6581405358.csv
# Min x: 120.44787277567336, Min y: 23.366222199720998
# Max x: 120.44849215189807, Max y: 23.367083330752948
# Mean x: 120.44815968736516, Mean y: 23.366721172452454
# Saved to ./data/csv/飛行軌跡_20230907135247_R5160023774.csv
# Copied to ./data/飛行軌跡_20230907135247_R5160023774.csv
# Min x: 120.38372549944151, Min y: 23.401989379784784
# Max x: 120.38476916742827, Max y: 23.402480552639467
# Mean x: 120.38440921268614, Mean y: 23.402286064203007
# Saved to ./data/csv/飛行軌跡_20230825064730_R2733774689.csv
# Copied to ./data/飛行軌跡_20230825064730_R2733774689.csv
# Min x: 120.40103676910928, Min y: 23.381575598910846
# Max x: 120.40176965813224, Max y: 23.382736584485766
# Mean x: 120.40128528863384, Mean y: 23.38207019480246
# Saved to ./data/csv/飛行軌跡_20230818123453_R1555137877.csv
# Copied to ./data/飛行軌跡_20230818123453_R1555137877.csv
# Min x: 120.40229471057593, Min y: 23.379571524390368
# Max x: 120.40276814386053, Max y: 23.38044592381297
# Mean x: 120.4026218569294, Mean y: 23.380070419517462
# Saved to ./data/csv/飛行軌跡_20231009091037_R6773926475.csv
# Copied to ./data/飛行軌跡_20231009091037_R6773926475.csv
# Min x: 120.33217254629851, Min y: 23.196891255878164
# Max x: 120.33280693796529, Max y: 23.197593134599774
# Mean x: 120.33244709813385, Mean y: 23.19720783167845
# Saved to ./data/csv/飛行軌跡_20230906085816_R1088370394.csv
# Copied to ./data/飛行軌跡_20230906085816_R1088370394.csv
# Min x: 120.41659958547125, Min y: 23.401248759260792
# Max x: 120.41670270139642, Max y: 23.40222249463481
# Mean x: 120.41663899645653, Mean y: 23.40163627775577
# Saved to ./data/csv/飛行軌跡_20230908105629_R4235902408.csv
# Copied to ./data/飛行軌跡_20230908105629_R4235902408.csv
# Min x: 120.41396053135527, Min y: 23.371764463924894
# Max x: 120.41471376614824, Max y: 23.37190075738549
# Mean x: 120.41411000078904, Mean y: 23.37185748586728
# Saved to ./data/csv/飛行軌跡_20230918131244_R7700556894.csv
# Copied to ./data/飛行軌跡_20230918131244_R7700556894.csv
# Min x: 120.41080103136531, Min y: 23.353197259732568
# Max x: 120.4110266974035, Max y: 23.353934460930322
# Mean x: 120.41086425759677, Mean y: 23.35344146526244
# Saved to ./data/csv/飛行軌跡_20230907141501_R0436164743.csv
# Copied to ./data/飛行軌跡_20230907141501_R0436164743.csv
# Min x: 120.39690745096472, Min y: 23.361086790504864
# Max x: 120.39794034433933, Max y: 23.361519788904364
# Mean x: 120.39732519816235, Mean y: 23.36132604001634
# Saved to ./data/csv/飛行軌跡_20230914064252_R2448016545.csv
# Copied to ./data/飛行軌跡_20230914064252_R2448016545.csv
# Min x: 120.40293633878079, Min y: 23.39235612316616
# Max x: 120.4033452962261, Max y: 23.393303021794505
# Mean x: 120.4031505744836, Mean y: 23.3927438801284
# Saved to ./data/csv/飛行軌跡_20230915093700_R5586465340.csv
# Copied to ./data/飛行軌跡_20230915093700_R5586465340.csv
# Min x: 120.38840039539292, Min y: 23.378459538781296
# Max x: 120.38848112096979, Max y: 23.379273936286932
# Mean x: 120.38843897196887, Mean y: 23.37881391399565
# Saved to ./data/csv/飛行軌跡_20230722142341_R1010830110.csv
# Copied to ./data/飛行軌跡_20230722142341_R1010830110.csv
# Min x: 120.39349012749676, Min y: 23.380297138248096
# Max x: 120.3938600048604, Max y: 23.38131822181561
# Mean x: 120.39368396258142, Mean y: 23.38076215199461
# Saved to ./data/csv/飛行軌跡_20230804101259_R4956290324.csv
# Copied to ./data/飛行軌跡_20230804101259_R4956290324.csv
# Min x: 120.45013817970431, Min y: 23.377552400907916
# Max x: 120.45087591574226, Max y: 23.378742132972366
# Mean x: 120.45054795178648, Mean y: 23.37825482077896
# Saved to ./data/csv/飛行軌跡_20230911120546_R5313678636.csv
# Copied to ./data/飛行軌跡_20230911120546_R5313678636.csv
# Min x: 120.44924906613137, Min y: 23.36898730914761
# Max x: 120.44959612299671, Max y: 23.369895488126406
# Mean x: 120.44936594332582, Mean y: 23.369568150730945
# Saved to ./data/csv/飛行軌跡_20230907131956_R6034672035.csv
# Copied to ./data/飛行軌跡_20230907131956_R6034672035.csv
# Min x: 120.42470231868836, Min y: 23.419679957568352
# Max x: 120.42522767812407, Max y: 23.420034400246326
# Mean x: 120.42504181892471, Mean y: 23.419906942824003
# Saved to ./data/csv/飛行軌跡_20230826124707_R4068658309.csv
# Copied to ./data/飛行軌跡_20230826124707_R4068658309.csv
# Min x: 120.334515833775, Min y: 23.347199308294723
# Max x: 120.3353044049273, Max y: 23.347626567614643
# Mean x: 120.33490566065902, Mean y: 23.34747563684417
# Saved to ./data/csv/飛行軌跡_20230926072332_R5048518794.csv
# Copied to ./data/飛行軌跡_20230926072332_R5048518794.csv
# Min x: 120.38221805654635, Min y: 23.401397332030243
# Max x: 120.38258964768225, Max y: 23.40206816718981
# Mean x: 120.38234403318309, Mean y: 23.40169974878924
# Saved to ./data/csv/飛行軌跡_20230825064320_R3472168055.csv
# Copied to ./data/飛行軌跡_20230825064320_R3472168055.csv
# Min x: 120.40441304584076, Min y: 23.391241703607
# Max x: 120.40513902855113, Max y: 23.392593433097364
# Mean x: 120.40485673451906, Mean y: 23.391764342731644
# Saved to ./data/csv/飛行軌跡_20230927105332_R6796651794.csv
# Copied to ./data/飛行軌跡_20230927105332_R6796651794.csv
# Min x: 120.41538629557148, Min y: 23.384248665723792
# Max x: 120.41562920733075, Max y: 23.385007272221063
# Mean x: 120.41549681388848, Mean y: 23.384777642254154
# Saved to ./data/csv/飛行軌跡_20230927101231_R3712696307.csv
# Copied to ./data/飛行軌跡_20230927101231_R3712696307.csv
# Min x: 120.42105345486856, Min y: 23.38166699946736
# Max x: 120.4218111701602, Max y: 23.381969382268515
# Mean x: 120.42141896737422, Mean y: 23.381809965131172
# Saved to ./data/csv/飛行軌跡_20230724105620_R8265040395.csv
# Copied to ./data/飛行軌跡_20230724105620_R8265040395.csv
# Min x: 120.21739805324866, Min y: 23.29088581995191
# Max x: 120.21813477808729, Max y: 23.292640138969958
# Mean x: 120.21783478741429, Mean y: 23.291525996875915
# Saved to ./data/csv/飛行軌跡_20231102102641_R1930251722.csv
# Copied to ./data/飛行軌跡_20231102102641_R1930251722.csv
# Min x: 120.44067578504942, Min y: 23.389530877139215
# Max x: 120.44093958076539, Max y: 23.389931608155415
# Mean x: 120.4408589481986, Mean y: 23.389703339748056
# Saved to ./data/csv/飛行軌跡_20230729140110_R2393025879.csv
# Copied to ./data/飛行軌跡_20230729140110_R2393025879.csv
# Min x: 120.40173701254238, Min y: 23.373893993963375
# Max x: 120.40206414188216, Max y: 23.374746983128308
# Mean x: 120.40188847452256, Mean y: 23.374360855183237
# Saved to ./data/csv/飛行軌跡_20231026104713_R6867525708.csv
# Copied to ./data/飛行軌跡_20231026104713_R6867525708.csv
# Min x: 120.43072690748114, Min y: 23.375122151948453
# Max x: 120.43081109663407, Max y: 23.375713049866714
# Mean x: 120.43074135335804, Mean y: 23.37534052027988
# Saved to ./data/csv/飛行軌跡_20230717155442_R6212287827.csv
# Copied to ./data/飛行軌跡_20230717155442_R6212287827.csv
# Min x: 120.4085577989243, Min y: 23.387131094637404
# Max x: 120.40940912629004, Max y: 23.388103209158825
# Mean x: 120.40879151294456, Mean y: 23.387402279941643
# Saved to ./data/csv/飛行軌跡_20230929091300_R8496859948.csv
# Copied to ./data/飛行軌跡_20230929091300_R8496859948.csv
# Min x: 120.39550656574598, Min y: 23.392201785836228
# Max x: 120.39595696173537, Max y: 23.39313757159227
# Mean x: 120.39578064376698, Mean y: 23.392611224854214
# Saved to ./data/csv/飛行軌跡_20231026093128_R3662468441.csv
# Copied to ./data/飛行軌跡_20231026093128_R3662468441.csv
# Min x: 120.40884179057306, Min y: 23.378685153513395
# Max x: 120.40956032133931, Max y: 23.379710401428376
# Mean x: 120.40934844003735, Mean y: 23.37920579810201
# Saved to ./data/csv/飛行軌跡_20231028090523_R0360397960.csv
# Copied to ./data/飛行軌跡_20231028090523_R0360397960.csv
# Min x: 120.44739204104724, Min y: 23.368416827290325
# Max x: 120.44780647998664, Max y: 23.36924001560646
# Mean x: 120.44754960058164, Mean y: 23.368965764681704
# Saved to ./data/csv/飛行軌跡_20230822153340_R6251383837.csv
# Copied to ./data/飛行軌跡_20230822153340_R6251383837.csv
# Min x: 120.40965609837943, Min y: 23.39002339365936
# Max x: 120.41013876656781, Max y: 23.390669317735966
# Mean x: 120.40990716523144, Mean y: 23.390383153205775
# Saved to ./data/csv/飛行軌跡_20230718142814_R3806981232.csv
# Copied to ./data/飛行軌跡_20230718142814_R3806981232.csv
# Min x: 120.41382363568673, Min y: 23.399262614586764
# Max x: 120.41401755954628, Max y: 23.40011807280459
# Mean x: 120.41391972566112, Mean y: 23.399653605006055
# Saved to ./data/csv/飛行軌跡_20231030065235_R1860405272.csv
# Copied to ./data/飛行軌跡_20231030065235_R1860405272.csv
# Min x: 120.24316566027473, Min y: 23.287605670495555
# Max x: 120.24383463292126, Max y: 23.28838907493394
# Mean x: 120.24341503498214, Mean y: 23.28814831090466
# Saved to ./data/csv/飛行軌跡_20231109063021_R0000709027.csv
# Copied to ./data/飛行軌跡_20231109063021_R0000709027.csv
# Min x: 120.40131535516653, Min y: 23.391643698377976
# Max x: 120.40218519844049, Max y: 23.39249583664306
# Mean x: 120.4017642507222, Mean y: 23.392165523496427
# Saved to ./data/csv/飛行軌跡_20231025063517_R8364544325.csv
# Copied to ./data/飛行軌跡_20231025063517_R8364544325.csv
# Min x: 120.23504067745344, Min y: 23.295143638670567
# Max x: 120.23557418401288, Max y: 23.296030200305932
# Mean x: 120.23532724898342, Mean y: 23.295496151490056
# Saved to ./data/csv/飛行軌跡_20231111072517_R7560597884.csv
# Copied to ./data/飛行軌跡_20231111072517_R7560597884.csv
# Min x: 120.41504210323346, Min y: 23.383747012562544
# Max x: 120.41555630597725, Max y: 23.384219526520063
# Mean x: 120.4152123598015, Mean y: 23.383968798507635
# Saved to ./data/csv/飛行軌跡_20230822104820_R1561263035.csv
# Copied to ./data/飛行軌跡_20230822104820_R1561263035.csv
# Min x: 120.36127176217693, Min y: 23.39055739607291
# Max x: 120.36251423992303, Max y: 23.391277711920207
# Mean x: 120.36181732659833, Mean y: 23.390871368746687
# Saved to ./data/csv/飛行軌跡_20230919093350_R4620381201.csv
# Copied to ./data/飛行軌跡_20230919093350_R4620381201.csv
# Min x: 120.41340676156136, Min y: 23.39918286549921
# Max x: 120.41363648903575, Max y: 23.39925204558063
# Mean x: 120.41353021909303, Mean y: 23.399225379045664
# Saved to ./data/csv/飛行軌跡_20231006061022_R2355730699.csv
# Copied to ./data/飛行軌跡_20231006061022_R2355730699.csv
# Min x: 120.41128979991281, Min y: 23.404243071904272
# Max x: 120.41139387102821, Max y: 23.40513381631
# Mean x: 120.41133078045472, Mean y: 23.404786259977463
# Saved to ./data/csv/飛行軌跡_20230808143813_R4181982456.csv
# Copied to ./data/飛行軌跡_20230808143813_R4181982456.csv
# Min x: 120.39961773374598, Min y: 23.402663091304014
# Max x: 120.39987735886068, Max y: 23.403476462669477
# Mean x: 120.39978026242301, Mean y: 23.402946354061537
# Saved to ./data/csv/飛行軌跡_20230915145217_R7227286126.csv
# Copied to ./data/飛行軌跡_20230915145217_R7227286126.csv
# Min x: 120.44128556878655, Min y: 23.38929751868581
# Max x: 120.44204454044197, Max y: 23.38991316197983
# Mean x: 120.44164386756421, Mean y: 23.38969260960506
# Saved to ./data/csv/飛行軌跡_20231022094920_R5209206443.csv
# Copied to ./data/飛行軌跡_20231022094920_R5209206443.csv
# Min x: 120.38801012440355, Min y: 23.367805892646786
# Max x: 120.3884356371571, Max y: 23.368729640000712
# Mean x: 120.38821796739276, Mean y: 23.368281538368713
# Saved to ./data/csv/飛行軌跡_20231016071217_R3414010577.csv
# Copied to ./data/飛行軌跡_20231016071217_R3414010577.csv
# Min x: 120.39952556884752, Min y: 23.357081932260684
# Max x: 120.40003548763235, Max y: 23.358063772826718
# Mean x: 120.39974534632549, Mean y: 23.35765059023613
# Saved to ./data/csv/飛行軌跡_20230914070319_R5590577612.csv
# Copied to ./data/飛行軌跡_20230914070319_R5590577612.csv
# Min x: 120.45352487132884, Min y: 23.369374501427313
# Max x: 120.45391911075883, Max y: 23.370356392396946
# Mean x: 120.4536666685238, Mean y: 23.369985644335618
# Saved to ./data/csv/飛行軌跡_20230930111520_R3158759596.csv
# Copied to ./data/飛行軌跡_20230930111520_R3158759596.csv
# Min x: 120.41206848438432, Min y: 23.384764734575292
# Max x: 120.41237769586806, Max y: 23.385932151642148
# Mean x: 120.41222039622394, Mean y: 23.385241473081752
# Saved to ./data/csv/飛行軌跡_20231031091716_R2671901688.csv
# Copied to ./data/飛行軌跡_20231031091716_R2671901688.csv
# Min x: 120.41010340952332, Min y: 23.403074004316146
# Max x: 120.41035306187374, Max y: 23.404042219569124
# Mean x: 120.41022632289497, Mean y: 23.403453200597855
# Saved to ./data/csv/飛行軌跡_20230811060755_R2246625456.csv
# Copied to ./data/飛行軌跡_20230811060755_R2246625456.csv
# Min x: 120.38166199295225, Min y: 23.398854153003374
# Max x: 120.38316716007778, Max y: 23.40004337153475
# Mean x: 120.38271048055365, Mean y: 23.39946583034834
# Saved to ./data/csv/飛行軌跡_20230803170844_R5284604712.csv
# Copied to ./data/飛行軌跡_20230803170844_R5284604712.csv
# Min x: 120.40717017073543, Min y: 23.35711623324857
# Max x: 120.40747946438889, Max y: 23.35806000270249
# Mean x: 120.40735512042832, Mean y: 23.35772465062358
# Saved to ./data/csv/飛行軌跡_20230716145450_R4827460167.csv
# Copied to ./data/飛行軌跡_20230716145450_R4827460167.csv
# Min x: 120.40470599231956, Min y: 23.379104515606453
# Max x: 120.405497588834, Max y: 23.380392534226086
# Mean x: 120.4052643570971, Mean y: 23.379800554516233
# Saved to ./data/csv/飛行軌跡_20231105065303_R1858539852.csv
# Copied to ./data/飛行軌跡_20231105065303_R1858539852.csv
# Min x: 120.40427288759787, Min y: 23.383857383323775
# Max x: 120.4045951066135, Max y: 23.384680292451534
# Mean x: 120.40449090918139, Mean y: 23.38413709735685
# Saved to ./data/csv/飛行軌跡_20230930134843_R4159886946.csv
# Copied to ./data/飛行軌跡_20230930134843_R4159886946.csv
# Min x: 120.44917232503248, Min y: 23.369073098198193
# Max x: 120.44967955554083, Max y: 23.369854120861866
# Mean x: 120.44942489391724, Mean y: 23.369545634988924
# Saved to ./data/csv/飛行軌跡_20230822151723_R5365510023.csv
# Copied to ./data/飛行軌跡_20230822151723_R5365510023.csv
# Min x: 120.25450848081778, Min y: 23.267511949054867
# Max x: 120.2547290951895, Max y: 23.268455642167336
# Mean x: 120.25462983425109, Mean y: 23.26817041754917
# Saved to ./data/csv/飛行軌跡_20231109113403_R0795205530.csv
# Copied to ./data/飛行軌跡_20231109113403_R0795205530.csv
# Min x: 120.2352499004768, Min y: 23.295152694117103
# Max x: 120.23574807482606, Max y: 23.296103618699913
# Mean x: 120.23551880920994, Mean y: 23.295544732919193
# Saved to ./data/csv/飛行軌跡_20231111071925_R5035316089.csv
# Copied to ./data/飛行軌跡_20231111071925_R5035316089.csv
# Min x: 120.24658137609013, Min y: 23.29957065396769
# Max x: 120.24726773272538, Max y: 23.300452714441768
# Mean x: 120.2469284621662, Mean y: 23.300053369564544
# Saved to ./data/csv/飛行軌跡_20231111080008_R7302250083.csv
# Copied to ./data/飛行軌跡_20231111080008_R7302250083.csv
# Min x: 120.42369601627595, Min y: 23.414176896090964
# Max x: 120.42422643225434, Max y: 23.41501226146593
# Mean x: 120.42390202520698, Mean y: 23.41457872823945
# Saved to ./data/csv/飛行軌跡_20230720130748_R4091313653.csv
# Copied to ./data/飛行軌跡_20230720130748_R4091313653.csv
# Min x: 120.42580651643358, Min y: 23.358359891067717
# Max x: 120.42672393462006, Max y: 23.358988886915306
# Mean x: 120.42640468436953, Mean y: 23.35857023069108
# Saved to ./data/csv/飛行軌跡_20230916075118_R8288878168.csv
# Copied to ./data/飛行軌跡_20230916075118_R8288878168.csv
# Min x: 120.40058625417336, Min y: 23.392604713097253
# Max x: 120.40090143728965, Max y: 23.393601639864855
# Mean x: 120.40072475106118, Mean y: 23.393094900682033
# Saved to ./data/csv/飛行軌跡_20230930102728_R6278100083.csv
# Copied to ./data/飛行軌跡_20230930102728_R6278100083.csv
# Min x: 120.4077317173328, Min y: 23.38431192007974
# Max x: 120.40892369538653, Max y: 23.385393447548395
# Mean x: 120.40829944654584, Mean y: 23.38498928638843
# Saved to ./data/csv/飛行軌跡_20230826055615_R2505523780.csv
# Copied to ./data/飛行軌跡_20230826055615_R2505523780.csv
# Min x: 120.44368818371365, Min y: 23.365682431477296
# Max x: 120.4443670876953, Max y: 23.36691797007876
# Mean x: 120.44410256712287, Mean y: 23.3661423887553
# Saved to ./data/csv/飛行軌跡_20231001082001_R5944420700.csv
# Copied to ./data/飛行軌跡_20231001082001_R5944420700.csv
# Min x: 120.39912570694631, Min y: 23.357187762769872
# Max x: 120.39964618577422, Max y: 23.358159175536148
# Mean x: 120.39936610115977, Mean y: 23.357759835813866
# Saved to ./data/csv/飛行軌跡_20230914071245_R1222242681.csv
# Copied to ./data/飛行軌跡_20230914071245_R1222242681.csv
# Min x: 120.43874546156697, Min y: 23.370460872402365
# Max x: 120.4388607522501, Max y: 23.371405805004983
# Mean x: 120.43880437837348, Mean y: 23.371040388115503
# Saved to ./data/csv/飛行軌跡_20231019064004_R8104195952.csv
# Copied to ./data/飛行軌跡_20231019064004_R8104195952.csv
# Min x: 120.2653238836662, Min y: 23.294766802902476
# Max x: 120.26624383308928, Max y: 23.29541223882694
# Mean x: 120.26585413389122, Mean y: 23.295120255478178
# Saved to ./data/csv/飛行軌跡_20231027073919_R5056105409.csv
# Copied to ./data/飛行軌跡_20231027073919_R5056105409.csv
# Min x: 120.34676655131425, Min y: 23.36148937461231
# Max x: 120.34756569214119, Max y: 23.361738865494686
# Mean x: 120.34717129992927, Mean y: 23.361635612606253
# Saved to ./data/csv/飛行軌跡_20230927063618_R6031433453.csv
# Copied to ./data/飛行軌跡_20230927063618_R6031433453.csv
# Min x: 120.40505959359697, Min y: 23.391821031134022
# Max x: 120.40568607772242, Max y: 23.3927700405872
# Mean x: 120.40544516869966, Mean y: 23.39253555983329
# Saved to ./data/csv/飛行軌跡_20230927110753_R0280043776.csv
# Copied to ./data/飛行軌跡_20230927110753_R0280043776.csv
# Min x: 120.39579710341121, Min y: 23.39215660717236
# Max x: 120.39626872233866, Max y: 23.393101857891512
# Mean x: 120.39605373934914, Mean y: 23.39256665617491
# Saved to ./data/csv/飛行軌跡_20231023092343_R1942967269.csv
# Copied to ./data/飛行軌跡_20231023092343_R1942967269.csv
# Min x: 120.40711965782471, Min y: 23.35718632033177
# Max x: 120.4074824287053, Max y: 23.358049636355325
# Mean x: 120.40730382428632, Mean y: 23.357696445944974
# Saved to ./data/csv/飛行軌跡_20230716145225_R0708676043.csv
# Copied to ./data/飛行軌跡_20230716145225_R0708676043.csv
# Min x: 120.44344890782041, Min y: 23.366945977330317
# Max x: 120.44400809452533, Max y: 23.36796879271464
# Mean x: 120.44378114487944, Mean y: 23.367598907102956
# Saved to ./data/csv/飛行軌跡_20231001085037_R5843812402.csv
# Copied to ./data/飛行軌跡_20231001085037_R5843812402.csv
# Min x: 120.439587476349, Min y: 23.3834384778377
# Max x: 120.44003518594891, Max y: 23.383755423951172
# Mean x: 120.4397934289054, Mean y: 23.3836003857428
# Saved to ./data/csv/飛行軌跡_20230930064551_R6900793606.csv
# Copied to ./data/飛行軌跡_20230930064551_R6900793606.csv
# Min x: 120.41703696905839, Min y: 23.36406811798593
# Max x: 120.41745699019219, Max y: 23.364913550116707
# Mean x: 120.41722985733132, Mean y: 23.36446595273067
# Saved to ./data/csv/飛行軌跡_20230809055118_R3888880672.csv
# Copied to ./data/飛行軌跡_20230809055118_R3888880672.csv
# Min x: 120.45245503780001, Min y: 23.3742528289837
# Max x: 120.4529495040492, Max y: 23.375178225791807
# Mean x: 120.45271148947289, Mean y: 23.374726905936743
# Saved to ./data/csv/飛行軌跡_20231022083413_R4255954683.csv
# Copied to ./data/飛行軌跡_20231022083413_R4255954683.csv
# Min x: 120.40453800078936, Min y: 23.387907256099425
# Max x: 120.40542622707922, Max y: 23.388735822009583
# Mean x: 120.4049929860146, Mean y: 23.38839809269132
# Saved to ./data/csv/飛行軌跡_20231026085619_R4052672640.csv
# Copied to ./data/飛行軌跡_20231026085619_R4052672640.csv
# Min x: 120.42194387497655, Min y: 23.373433166162023
# Max x: 120.42215288555269, Max y: 23.374352447101177
# Mean x: 120.422060817455, Mean y: 23.373977983025544
# Saved to ./data/csv/飛行軌跡_20230918133825_R2496156735.csv
# Copied to ./data/飛行軌跡_20230918133825_R2496156735.csv
# Min x: 120.33807073577165, Min y: 23.34690451291943
# Max x: 120.33841180528896, Max y: 23.347844269845005
# Mean x: 120.33824470864029, Mean y: 23.347186933949857
# Saved to ./data/csv/飛行軌跡_20231019071340_R3396939783.csv
# Copied to ./data/飛行軌跡_20231019071340_R3396939783.csv
# Min x: 120.40850321594561, Min y: 23.397099399748747
# Max x: 120.4085570305576, Max y: 23.398021151552033
# Mean x: 120.40853591061476, Mean y: 23.39749715373458
# Saved to ./data/csv/飛行軌跡_20230720113011_R0809585883.csv
# Copied to ./data/飛行軌跡_20230720113011_R0809585883.csv
# Min x: 120.41951324627776, Min y: 23.383202699667123
# Max x: 120.41974713309838, Max y: 23.38427174480627
# Mean x: 120.41961373785671, Mean y: 23.383959449177063
# Saved to ./data/csv/飛行軌跡_20230825151121_R7317377379.csv
# Copied to ./data/飛行軌跡_20230825151121_R7317377379.csv
# Min x: 120.22704596227756, Min y: 23.30091971328532
# Max x: 120.22753777684413, Max y: 23.301190174331506
# Mean x: 120.22732855737071, Mean y: 23.301038892211444
# Saved to ./data/csv/飛行軌跡_20231105082824_R6873927780.csv
# Copied to ./data/飛行軌跡_20231105082824_R6873927780.csv
# Min x: 120.40090380313106, Min y: 23.380424492799822
# Max x: 120.40124529772714, Max y: 23.381316444662573
# Mean x: 120.4010641303501, Mean y: 23.380867722150644
# Saved to ./data/csv/飛行軌跡_20231019085020_R1061116526.csv
# Copied to ./data/飛行軌跡_20231019085020_R1061116526.csv
# Min x: 120.40390879321251, Min y: 23.383901007250262
# Max x: 120.40421930279403, Max y: 23.384717812566677
# Mean x: 120.40408534571537, Mean y: 23.384119951360017
# Saved to ./data/csv/飛行軌跡_20230930135803_R4380134963.csv
# Copied to ./data/飛行軌跡_20230930135803_R4380134963.csv
# Min x: 120.41379921865207, Min y: 23.40117252415151
# Max x: 120.41422709194079, Max y: 23.40209313712691
# Mean x: 120.41396354076619, Mean y: 23.40156683397074
# Saved to ./data/csv/飛行軌跡_20230914071850_R1164615913.csv
# Copied to ./data/飛行軌跡_20230914071850_R1164615913.csv
# Min x: 120.45035534312979, Min y: 23.376787057693946
# Max x: 120.4509583251911, Max y: 23.377613064481057
# Mean x: 120.4506725126335, Mean y: 23.37725910675899
# Saved to ./data/csv/飛行軌跡_20231028112709_R7327240876.csv
# Copied to ./data/飛行軌跡_20231028112709_R7327240876.csv
# Min x: 120.3924273845173, Min y: 23.370685951981727
# Max x: 120.39255706780605, Max y: 23.371631914838982
# Mean x: 120.39249405706502, Mean y: 23.37092647581769
# Saved to ./data/csv/飛行軌跡_20230912074013_R0513509211.csv
# Copied to ./data/飛行軌跡_20230912074013_R0513509211.csv
# Min x: 120.38523420780427, Min y: 23.361289329894845
# Max x: 120.38719612597451, Max y: 23.361926568535118
# Mean x: 120.3859567568409, Mean y: 23.361625441759898
# Saved to ./data/csv/飛行軌跡_20230907074520_R3180801941.csv
# Copied to ./data/飛行軌跡_20230907074520_R3180801941.csv
# Min x: 120.4105659325732, Min y: 23.357111562731188
# Max x: 120.41081867258598, Max y: 23.357213969034525
# Mean x: 120.41069230257959, Mean y: 23.357162765882855
# Saved to ./data/csv/飛行軌跡_20231020084336_R2108472695.csv
# Copied to ./data/飛行軌跡_20231020084336_R2108472695.csv
# Min x: 120.42845640562768, Min y: 23.390667376603965
# Max x: 120.42942939660428, Max y: 23.391302508980473
# Mean x: 120.42911229557173, Mean y: 23.391039647861515
# Saved to ./data/csv/飛行軌跡_20230909091557_R2201743963.csv
# Copied to ./data/飛行軌跡_20230909091557_R2201743963.csv
# Min x: 120.45030447897486, Min y: 23.377636276103004
# Max x: 120.45081916382355, Max y: 23.378614426754787
# Mean x: 120.45057218049904, Mean y: 23.37807384442297
# Saved to ./data/csv/飛行軌跡_20231017075228_R2864940295.csv
# Copied to ./data/飛行軌跡_20231017075228_R2864940295.csv
# Min x: 120.38881212347435, Min y: 23.378509854771703
# Max x: 120.38891816599339, Max y: 23.379233362258198
# Mean x: 120.38885045957136, Mean y: 23.378758285882945
# Saved to ./data/csv/飛行軌跡_20230804085741_R4208641343.csv
# Copied to ./data/飛行軌跡_20230804085741_R4208641343.csv
# Min x: 120.229954155358, Min y: 23.29842283498651
# Max x: 120.23062868762742, Max y: 23.29938714730705
# Mean x: 120.23034547573135, Mean y: 23.29905706753943
# Saved to ./data/csv/飛行軌跡_20231106084634_R5251482770.csv
# Copied to ./data/飛行軌跡_20231106084634_R5251482770.csv
# Min x: 120.4190881894047, Min y: 23.383252963106848
# Max x: 120.41936569655253, Max y: 23.384282711747
# Mean x: 120.41927340431047, Mean y: 23.383964531055565
# Saved to ./data/csv/飛行軌跡_20230825152953_R7270492915.csv
# Copied to ./data/飛行軌跡_20230825152953_R7270492915.csv
# Min x: 120.40764978955526, Min y: 23.384354080339325
# Max x: 120.40846350693572, Max y: 23.38536169389401
# Mean x: 120.40801540598613, Mean y: 23.384813431174223
# Saved to ./data/csv/飛行軌跡_20231028082550_R0365292020.csv
# Copied to ./data/飛行軌跡_20231028082550_R0365292020.csv
# Min x: 120.41033742973973, Min y: 23.397121258748317
# Max x: 120.41047200302177, Max y: 23.398124819176118
# Mean x: 120.41041992490112, Mean y: 23.397468838945063
# Saved to ./data/csv/飛行軌跡_20230812133931_R2134979318.csv
# Copied to ./data/飛行軌跡_20230812133931_R2134979318.csv
# Min x: 120.36804992219847, Min y: 23.365122692685453
# Max x: 120.36846667532784, Max y: 23.36567706112203
# Mean x: 120.36828504785916, Mean y: 23.365398206745237
# Saved to ./data/csv/飛行軌跡_20230922102652_R5265938198.csv
# Copied to ./data/飛行軌跡_20230922102652_R5265938198.csv
# Min x: 120.42439324786075, Min y: 23.373830203786053
# Max x: 120.42463037083085, Max y: 23.37491530337038
# Mean x: 120.42446942823939, Mean y: 23.374179833789764
# Saved to ./data/csv/飛行軌跡_20230816083942_R0082722011.csv
# Copied to ./data/飛行軌跡_20230816083942_R0082722011.csv
# Min x: 120.40294462077115, Min y: 23.353087952276734
# Max x: 120.40337455219455, Max y: 23.35503287143443
# Mean x: 120.40320972196841, Mean y: 23.35407730352248
# Saved to ./data/csv/飛行軌跡_20231023083416_R7860373252.csv
# Copied to ./data/飛行軌跡_20231023083416_R7860373252.csv
# Min x: 120.44005317184555, Min y: 23.366806603982326
# Max x: 120.44062737052609, Max y: 23.36771340442898
# Mean x: 120.44042233885281, Mean y: 23.367062496514176
# Saved to ./data/csv/飛行軌跡_20231001090326_R6425928326.csv
# Copied to ./data/飛行軌跡_20231001090326_R6425928326.csv
# Min x: 120.39460523982325, Min y: 23.35420222832272
# Max x: 120.39535089897412, Max y: 23.355254104066933
# Mean x: 120.39506393344315, Mean y: 23.354660357194547
# Saved to ./data/csv/飛行軌跡_20231006103319_R4459523253.csv
# Copied to ./data/飛行軌跡_20231006103319_R4459523253.csv
# Min x: 120.40756918609306, Min y: 23.351593302650016
# Max x: 120.40887951867465, Max y: 23.353622772632953
# Mean x: 120.4080787883631, Mean y: 23.352437678001785
# Saved to ./data/csv/飛行軌跡_20231022104344_R0104423456.csv
# Copied to ./data/飛行軌跡_20231022104344_R0104423456.csv
# Min x: 120.42551919525057, Min y: 23.373560757937856
# Max x: 120.42590864342532, Max y: 23.37472972101036
# Mean x: 120.42571969044096, Mean y: 23.374109478887327
# Saved to ./data/csv/飛行軌跡_20231012083438_R1848432172.csv
# Copied to ./data/飛行軌跡_20231012083438_R1848432172.csv
# Min x: 120.39405697950978, Min y: 23.381310861529
# Max x: 120.39411061262503, Max y: 23.382251555480792
# Mean x: 120.39407864490967, Mean y: 23.38185346534107
# Saved to ./data/csv/飛行軌跡_20230811171631_R6154306352.csv
# Copied to ./data/飛行軌跡_20230811171631_R6154306352.csv
# Min x: 120.39489404870558, Min y: 23.394317466939167
# Max x: 120.39516015613596, Max y: 23.394396132499242
# Mean x: 120.39504631336662, Mean y: 23.3943598915932
# Saved to ./data/csv/飛行軌跡_20230915100641_R5028758146.csv
# Copied to ./data/飛行軌跡_20230915100641_R5028758146.csv
# Min x: 120.44371086782921, Min y: 23.3656975954797
# Max x: 120.44417759576717, Max y: 23.366864124588613
# Mean x: 120.44397406603878, Mean y: 23.36622638147495
# Saved to ./data/csv/飛行軌跡_20230824133651_R5213261658.csv
# Copied to ./data/飛行軌跡_20230824133651_R5213261658.csv
# Min x: 120.41084645440807, Min y: 23.35319989322582
# Max x: 120.41111197038458, Max y: 23.353992623109562
# Mean x: 120.41099601117448, Mean y: 23.35360292820848
# Saved to ./data/csv/飛行軌跡_20230907141735_R5421778946.csv
# Copied to ./data/飛行軌跡_20230907141735_R5421778946.csv
# Min x: 120.42989689035475, Min y: 23.342524040245646
# Max x: 120.43021253371717, Max y: 23.342711603190445
# Mean x: 120.43006712810511, Mean y: 23.342587456484484
# Saved to ./data/csv/飛行軌跡_20230930085408_R5234994643.csv
# Copied to ./data/飛行軌跡_20230930085408_R5234994643.csv
# Min x: 120.38639450718038, Min y: 23.357313867960364
# Max x: 120.38696423565538, Max y: 23.35832785027199
# Mean x: 120.38670975099801, Mean y: 23.357620773276327
# Saved to ./data/csv/飛行軌跡_20231006075342_R2919769386.csv
# Copied to ./data/飛行軌跡_20231006075342_R2919769386.csv
# Min x: 120.42589372123857, Min y: 23.35483098518568
# Max x: 120.42745590419263, Max y: 23.35516269609106
# Mean x: 120.42668471536344, Mean y: 23.355086886163022
# Saved to ./data/csv/飛行軌跡_20230919101725_R1675592417.csv
# Copied to ./data/飛行軌跡_20230919101725_R1675592417.csv
# Min x: 120.4367830270772, Min y: 23.36612985619807
# Max x: 120.43773420470336, Max y: 23.366799889863557
# Mean x: 120.43742971809381, Mean y: 23.36655269087498
# Saved to ./data/csv/飛行軌跡_20231102075915_R4127391525.csv
# Copied to ./data/飛行軌跡_20231102075915_R4127391525.csv
# Min x: 120.40562028228956, Min y: 23.355496919650715
# Max x: 120.40608914719897, Max y: 23.356425661960223
# Mean x: 120.40588530551678, Mean y: 23.355986104874646
# Saved to ./data/csv/飛行軌跡_20230810094508_R5835703197.csv
# Copied to ./data/飛行軌跡_20230810094508_R5835703197.csv
# Min x: 120.33129271494435, Min y: 23.196534280351866
# Max x: 120.33203213802629, Max y: 23.196939774788223
# Mean x: 120.33163989569452, Mean y: 23.196722329521137
# Saved to ./data/csv/飛行軌跡_20231007082140_R2944525911.csv
# Copied to ./data/飛行軌跡_20231007082140_R2944525911.csv
# Min x: 120.39870611377076, Min y: 23.374718817437195
# Max x: 120.39891756649634, Max y: 23.37560018002134
# Mean x: 120.39884043761906, Mean y: 23.374999011681513
# Saved to ./data/csv/飛行軌跡_20230912150452_R1467182650.csv
# Copied to ./data/飛行軌跡_20230912150452_R1467182650.csv
# Min x: 120.29886240702263, Min y: 23.347237837439504
# Max x: 120.29921884743247, Max y: 23.348186563906268
# Mean x: 120.29902353732322, Mean y: 23.347811384137366
# Saved to ./data/csv/飛行軌跡_20230822075508_R1331288468.csv
# Copied to ./data/飛行軌跡_20230822075508_R1331288468.csv
# Min x: 120.44711286424572, Min y: 23.369252399207326
# Max x: 120.44800445623564, Max y: 23.370199232589417
# Mean x: 120.44740445204977, Mean y: 23.36970947433479
# Saved to ./data/csv/飛行軌跡_20231022074936_R5736656663.csv
# Copied to ./data/飛行軌跡_20231022074936_R5736656663.csv
# Min x: 120.40700242060157, Min y: 23.381648651224207
# Max x: 120.40716104484672, Max y: 23.3823947542899
# Mean x: 120.4071017574349, Mean y: 23.381838883464038
# Saved to ./data/csv/飛行軌跡_20230731135232_R1673368398.csv
# Copied to ./data/飛行軌跡_20230731135232_R1673368398.csv
# Min x: 120.38932727018413, Min y: 23.360845903539932
# Max x: 120.39031296965375, Max y: 23.36133542357281
# Mean x: 120.38987378974109, Mean y: 23.361036080831386
# Saved to ./data/csv/飛行軌跡_20231023092115_R2209120938.csv
# Copied to ./data/飛行軌跡_20231023092115_R2209120938.csv
# Min x: 120.42298051004408, Min y: 23.398773666267424
# Max x: 120.42402332142389, Max y: 23.398944435940905
# Mean x: 120.42338968738612, Mean y: 23.3988555794307
# Saved to ./data/csv/飛行軌跡_20230827093236_R5332371875.csv
# Copied to ./data/飛行軌跡_20230827093236_R5332371875.csv
# Min x: 120.38200635270628, Min y: 23.374193454224145
# Max x: 120.38266072861137, Max y: 23.374380882046765
# Mean x: 120.38228157038195, Mean y: 23.374276950747998
# Saved to ./data/csv/飛行軌跡_20230816094801_R3751221981.csv
# Copied to ./data/飛行軌跡_20230816094801_R3751221981.csv
# Min x: 120.40622441829744, Min y: 23.387384740206244
# Max x: 120.40711992881934, Max y: 23.388237158153327
# Mean x: 120.40672614924313, Mean y: 23.38784477776803
# Saved to ./data/csv/飛行軌跡_20230814085736_R3359466520.csv
# Copied to ./data/飛行軌跡_20230814085736_R3359466520.csv
# Min x: 120.44213399838763, Min y: 23.37343672933978
# Max x: 120.44234921019925, Max y: 23.374402853108855
# Mean x: 120.44219649026238, Mean y: 23.374220192237278
# Saved to ./data/csv/飛行軌跡_20231024072218_R3544635575.csv
# Copied to ./data/飛行軌跡_20231024072218_R3544635575.csv
# Min x: 120.42545580942047, Min y: 23.368718829630605
# Max x: 120.42592728529331, Max y: 23.369578771004626
# Mean x: 120.42565232969717, Mean y: 23.36921071136357
# Saved to ./data/csv/飛行軌跡_20230721155034_R4208278533.csv
# Copied to ./data/飛行軌跡_20230721155034_R4208278533.csv
# Min x: 120.32164286457497, Min y: 23.345833826853788
# Max x: 120.32191410247532, Max y: 23.34677384664605
# Mean x: 120.32178872568119, Mean y: 23.346300440790753
# Saved to ./data/csv/飛行軌跡_20230926081823_R6719658124.csv
# Copied to ./data/飛行軌跡_20230926081823_R6719658124.csv
# Min x: 120.24792016757971, Min y: 23.29457278901829
# Max x: 120.2487113301518, Max y: 23.29531459338266
# Mean x: 120.24819827325194, Mean y: 23.29508652282536
# Saved to ./data/csv/飛行軌跡_20231102140632_R0537433484.csv
# Copied to ./data/飛行軌跡_20231102140632_R0537433484.csv
# Min x: 120.36125966667137, Min y: 23.370008840781033
# Max x: 120.36146607193491, Max y: 23.371223175363138
# Mean x: 120.36138700955061, Mean y: 23.37066602769435
# Saved to ./data/csv/飛行軌跡_20231021055604_R0487006497.csv
# Copied to ./data/飛行軌跡_20231021055604_R0487006497.csv
# Min x: 120.41382073347624, Min y: 23.379913714148906
# Max x: 120.41396700141247, Max y: 23.381069184183605
# Mean x: 120.41389121077152, Mean y: 23.380295649999965
# Saved to ./data/csv/飛行軌跡_20230717151452_R1992907719.csv
# Copied to ./data/飛行軌跡_20230717151452_R1992907719.csv
# Min x: 120.24325082167555, Min y: 23.29738554887918
# Max x: 120.24438991604408, Max y: 23.298108362642317
# Mean x: 120.24389253910074, Mean y: 23.29770453880437
# Saved to ./data/csv/飛行軌跡_20231025094910_R7778476211.csv
# Copied to ./data/飛行軌跡_20231025094910_R7778476211.csv
# Min x: 120.44786900829673, Min y: 23.366183543417037
# Max x: 120.44838980996659, Max y: 23.367112356818303
# Mean x: 120.44810545540194, Mean y: 23.366678897091667
# Saved to ./data/csv/飛行軌跡_20230717162810_R7683697250.csv
# Copied to ./data/飛行軌跡_20230717162810_R7683697250.csv
# Min x: 120.44375849898498, Min y: 23.38814504221183
# Max x: 120.44432322684261, Max y: 23.388930491605606
# Mean x: 120.4440714784681, Mean y: 23.388549465229616
# Saved to ./data/csv/飛行軌跡_20230907093842_R0214503921.csv
# Copied to ./data/飛行軌跡_20230907093842_R0214503921.csv
# Min x: 120.40237531015197, Min y: 23.380048422318946
# Max x: 120.40454862569524, Max y: 23.380713463995875
# Mean x: 120.4034789171792, Mean y: 23.380397327455487
# Saved to ./data/csv/飛行軌跡_20230826074946_R1803247946.csv
# Copied to ./data/飛行軌跡_20230826074946_R1803247946.csv
# Min x: 120.43793718189744, Min y: 23.3921758803098
# Max x: 120.438151332648, Max y: 23.393251536928446
# Mean x: 120.43805100579289, Mean y: 23.3928189151484
# Saved to ./data/csv/飛行軌跡_20230914112016_R8464978130.csv
# Copied to ./data/飛行軌跡_20230914112016_R8464978130.csv
# Min x: 120.39922926830464, Min y: 23.348624415362835
# Max x: 120.40020609623265, Max y: 23.350159682972965
# Mean x: 120.39994490650169, Mean y: 23.3492536563826
# Saved to ./data/csv/飛行軌跡_20230912072206_R3999390013.csv
# Copied to ./data/飛行軌跡_20230912072206_R3999390013.csv
# Min x: 120.3982888801465, Min y: 23.37468814207561
# Max x: 120.39917348460104, Max y: 23.375594299972867
# Mean x: 120.398815901162, Mean y: 23.375128431578116
# Saved to ./data/csv/飛行軌跡_20230730132718_R1526531281.csv
# Copied to ./data/飛行軌跡_20230730132718_R1526531281.csv
# Min x: 120.39917056692126, Min y: 23.377587481026723
# Max x: 120.39928129958739, Max y: 23.378483455874672
# Mean x: 120.39921263015148, Mean y: 23.378145304663693
# Saved to ./data/csv/飛行軌跡_20230804085038_R3763263563.csv
# Copied to ./data/飛行軌跡_20230804085038_R3763263563.csv
# Min x: 120.38769744100755, Min y: 23.382079236964046
# Max x: 120.38794445512015, Max y: 23.383160720754578
# Mean x: 120.38780164501844, Mean y: 23.382615619679587
# Saved to ./data/csv/飛行軌跡_20231018064027_R4786957039.csv
# Copied to ./data/飛行軌跡_20231018064027_R4786957039.csv
# Min x: 120.43005861059154, Min y: 23.368427089918626
# Max x: 120.43010543432086, Max y: 23.369289504553237
# Mean x: 120.4300767342304, Mean y: 23.369038463258736
# Saved to ./data/csv/飛行軌跡_20230808131241_R8543490331.csv
# Copied to ./data/飛行軌跡_20230808131241_R8543490331.csv
# Min x: 120.38154511004655, Min y: 23.390516448820208
# Max x: 120.38182662159288, Max y: 23.391615833786602
# Mean x: 120.38174291276758, Mean y: 23.39093056556197
# Saved to ./data/csv/飛行軌跡_20230901074729_R4380228073.csv
# Copied to ./data/飛行軌跡_20230901074729_R4380228073.csv
# Min x: 120.41321527417817, Min y: 23.36174493208667
# Max x: 120.4136419298857, Max y: 23.36268160150156
# Mean x: 120.41338663476104, Mean y: 23.36224339748765
# Saved to ./data/csv/飛行軌跡_20231103084215_R0135409657.csv
# Copied to ./data/飛行軌跡_20231103084215_R0135409657.csv
# Min x: 120.39676609956358, Min y: 23.360574835067577
# Max x: 120.39777975530129, Max y: 23.361014653709713
# Mean x: 120.39714117525835, Mean y: 23.360831087971686
# Saved to ./data/csv/飛行軌跡_20231006090305_R6628810013.csv
# Copied to ./data/飛行軌跡_20231006090305_R6628810013.csv
# Min x: 120.40801214566561, Min y: 23.378604294306868
# Max x: 120.40928967701558, Max y: 23.38000409379741
# Mean x: 120.40829441342372, Mean y: 23.379408525572103
# Saved to ./data/csv/飛行軌跡_20231008090552_R6858042737.csv
# Copied to ./data/飛行軌跡_20231008090552_R6858042737.csv
# Min x: 120.3842850114013, Min y: 23.367850975794852
# Max x: 120.38487229118473, Max y: 23.368331205727344
# Mean x: 120.38461085240343, Mean y: 23.36812016679904
# Saved to ./data/csv/飛行軌跡_20230912070317_R8276892452.csv
# Copied to ./data/飛行軌跡_20230912070317_R8276892452.csv
# Min x: 120.22593021813015, Min y: 23.293960365886516
# Max x: 120.22638441099465, Max y: 23.294099854103457
# Mean x: 120.22624065940064, Mean y: 23.29401262407438
# Saved to ./data/csv/飛行軌跡_20231102121046_R0231247035.csv
# Copied to ./data/飛行軌跡_20231102121046_R0231247035.csv
# Min x: 120.4012024020612, Min y: 23.39164038279391
# Max x: 120.40207662265497, Max y: 23.392500852971533
# Mean x: 120.40150748745202, Mean y: 23.392035302593477
# Saved to ./data/csv/飛行軌跡_20231009095249_R0387700480.csv
# Copied to ./data/飛行軌跡_20231009095249_R0387700480.csv
# Min x: 120.40833534809033, Min y: 23.397133988895348
# Max x: 120.40850512764958, Max y: 23.398073169440092
# Mean x: 120.40842209389791, Mean y: 23.397461647796828
# Saved to ./data/csv/飛行軌跡_20230823161945_R5760882193.csv
# Copied to ./data/飛行軌跡_20230823161945_R5760882193.csv
# Min x: 120.40391356961487, Min y: 23.382861822397633
# Max x: 120.40414911078025, Max y: 23.383736835565358
# Mean x: 120.4040072776421, Mean y: 23.383528245393737
# Saved to ./data/csv/飛行軌跡_20231029071012_R3040371996.csv
# Copied to ./data/飛行軌跡_20231029071012_R3040371996.csv
# Min x: 120.41384513416406, Min y: 23.38389721388172
# Max x: 120.41403918045297, Max y: 23.384652533955702
# Mean x: 120.41392124471948, Mean y: 23.384250359105508
# Saved to ./data/csv/飛行軌跡_20230927103203_R0516411406.csv
# Copied to ./data/飛行軌跡_20230927103203_R0516411406.csv
# Min x: 120.2154470320541, Min y: 23.288898531463513
# Max x: 120.21593572002831, Max y: 23.289883500817623
# Mean x: 120.21572540187762, Mean y: 23.28927549584765
# Saved to ./data/csv/飛行軌跡_20231115082241_R2378528694.csv
# Copied to ./data/飛行軌跡_20231115082241_R2378528694.csv
# Min x: 120.39837279667474, Min y: 23.37462165422958
# Max x: 120.39882716263348, Max y: 23.375516396506338
# Mean x: 120.39867492900056, Mean y: 23.374975405631826
# Saved to ./data/csv/飛行軌跡_20231015152234_R1110004867.csv
# Copied to ./data/飛行軌跡_20231015152234_R1110004867.csv
# Min x: 120.42204141611185, Min y: 23.374373623779604
# Max x: 120.4223902203678, Max y: 23.37542761735106
# Mean x: 120.42217738800403, Mean y: 23.37471909925363
# Saved to ./data/csv/飛行軌跡_20230918132457_R7451006087.csv
# Copied to ./data/飛行軌跡_20230918132457_R7451006087.csv
# Min x: 120.39803075791103, Min y: 23.390749102384028
# Max x: 120.39831554435322, Max y: 23.391858622835933
# Mean x: 120.39814213732487, Mean y: 23.39130956160088
# Saved to ./data/csv/飛行軌跡_20231029073402_R3510654069.csv
# Copied to ./data/飛行軌跡_20231029073402_R3510654069.csv
# Min x: 120.39913732713546, Min y: 23.374691872410285
# Max x: 120.3993771291194, Max y: 23.375596595967963
# Mean x: 120.3992387661564, Mean y: 23.375053909413094
# Saved to ./data/csv/飛行軌跡_20230805130844_R7327513898.csv
# Copied to ./data/飛行軌跡_20230805130844_R7327513898.csv
# Min x: 120.4041276498016, Min y: 23.385848074012888
# Max x: 120.40461742908056, Max y: 23.38680109238385
# Mean x: 120.40434976141862, Mean y: 23.38621968574208
# Saved to ./data/csv/飛行軌跡_20230913070609_R1382112204.csv
# Copied to ./data/飛行軌跡_20230913070609_R1382112204.csv
# Min x: 120.4139020344059, Min y: 23.39125809737514
# Max x: 120.41394166281411, Max y: 23.39220417129024
# Mean x: 120.41392656241831, Mean y: 23.39170618699076
# Saved to ./data/csv/飛行軌跡_20230719113622_R1405082008.csv
# Copied to ./data/飛行軌跡_20230719113622_R1405082008.csv
# Min x: 120.40250259199819, Min y: 23.390832651132403
# Max x: 120.40260629660605, Max y: 23.391192242396215
# Mean x: 120.4025380298349, Mean y: 23.390999014051463
# Saved to ./data/csv/飛行軌跡_20230811155523_R6333059528.csv
# ...
# Min x: 120.45426685057272, Min y: 23.36790820500749
# Max x: 120.45639821627942, Max y: 23.368693551945068
# Mean x: 120.4557976271931, Mean y: 23.368292306771984
# Saved to ./data/csv/飛行軌跡_20231024092612_R8220111139.csv
# Copied to ./data/飛行軌跡_20231024092612_R8220111139.csv
# Min x: 120.44081237391202, Min y: 23.372363391581576
# Max x: 120.44094570418689, Max y: 23.3732508461852
# Mean x: 120.44088871036378, Mean y: 23.37280763522053
# Saved to ./data/csv/飛行軌跡_20231019065108_R8034848068.csv
# Copied to ./data/飛行軌跡_20231019065108_R8034848068.csv
# Min x: 120.42207831365528, Min y: 23.367528316237635
# Max x: 120.42263868487859, Max y: 23.36830605066852
# Mean x: 120.4223710430218, Mean y: 23.36797771471004
# Saved to ./data/csv/飛行軌跡_20231017090312_R3620407458.csv
# Copied to ./data/飛行軌跡_20231017090312_R3620407458.csv
# Min x: 120.45901203909528, Min y: 23.370249580068776
# Max x: 120.45970328594221, Max y: 23.370707772566558
# Mean x: 120.4594904346316, Mean y: 23.370482391866087
# Saved to ./data/csv/飛行軌跡_20231024095154_R6618790628.csv
# Copied to ./data/飛行軌跡_20231024095154_R6618790628.csv
# Min x: 120.40962290093249, Min y: 23.397125324052073
# Max x: 120.40973909996671, Max y: 23.398085867255933
# Mean x: 120.4096749838968, Mean y: 23.397495147661935
# Saved to ./data/csv/飛行軌跡_20230720111638_R8104632361.csv
# Copied to ./data/飛行軌跡_20230720111638_R8104632361.csv
# Min x: 120.24193494758218, Min y: 23.26831451837151
# Max x: 120.24208196760377, Max y: 23.269141670863423
# Mean x: 120.24201472342642, Mean y: 23.268889306470857
# Saved to ./data/csv/飛行軌跡_20231109125101_R7602859196.csv
# Copied to ./data/飛行軌跡_20231109125101_R7602859196.csv
# Min x: 120.41741255490454, Min y: 23.381650260576624
# Max x: 120.4176107814334, Max y: 23.382515919935976
# Mean x: 120.4175311609791, Mean y: 23.382223654052655
# Saved to ./data/csv/飛行軌跡_20230821095016_R8270970928.csv
# Copied to ./data/飛行軌跡_20230821095016_R8270970928.csv
# Min x: 120.44244688095867, Min y: 23.364518066585433
# Max x: 120.44301245024202, Max y: 23.36508807323474
# Mean x: 120.44275950617323, Mean y: 23.36478520814624
# Saved to ./data/csv/飛行軌跡_20230911094453_R3154687873.csv
# Copied to ./data/飛行軌跡_20230911094453_R3154687873.csv
# Min x: 120.4272804693184, Min y: 23.374410484822185
# Max x: 120.42792517197927, Max y: 23.375549007566928
# Mean x: 120.42763249629999, Mean y: 23.37503320011463
# Saved to ./data/csv/飛行軌跡_20231012105622_R2131647324.csv
# Copied to ./data/飛行軌跡_20231012105622_R2131647324.csv
# Min x: 120.39835263417727, Min y: 23.374637926561984
# Max x: 120.39845277488406, Max y: 23.375555439595267
# Mean x: 120.39840357182126, Mean y: 23.375043589252755
# Saved to ./data/csv/飛行軌跡_20230721161908_R0459663747.csv
# Copied to ./data/飛行軌跡_20230721161908_R0459663747.csv
# Min x: 120.39874574528723, Min y: 23.373672468313277
# Max x: 120.3991071762674, Max y: 23.374698409485777
# Mean x: 120.39890072789625, Mean y: 23.37431891799152
# Saved to ./data/csv/飛行軌跡_20230906154724_R2530898706.csv
# Copied to ./data/飛行軌跡_20230906154724_R2530898706.csv
# Min x: 120.41811824850848, Min y: 23.376236155497292
# Max x: 120.41897820816641, Max y: 23.377404975556587
# Mean x: 120.41855840880183, Mean y: 23.376840962412942
# Saved to ./data/csv/飛行軌跡_20230724103230_R3167109092.csv
# Copied to ./data/飛行軌跡_20230724103230_R3167109092.csv
# Min x: 120.39708908116269, Min y: 23.39296594240702
# Max x: 120.39737094771161, Max y: 23.39398719607284
# Mean x: 120.39721798145216, Mean y: 23.393573705021222
# Saved to ./data/csv/飛行軌跡_20231028063538_R1855769806.csv
# Copied to ./data/飛行軌跡_20231028063538_R1855769806.csv
# Min x: 120.39912685827389, Min y: 23.370830758826145
# Max x: 120.39936267311397, Max y: 23.371794838875207
# Mean x: 120.39923797803165, Mean y: 23.371201827912184
# Saved to ./data/csv/飛行軌跡_20230930055227_R2368375365.csv
# Copied to ./data/飛行軌跡_20230930055227_R2368375365.csv
# Min x: 120.40465192283216, Min y: 23.383540179515347
# Max x: 120.40563909899205, Max y: 23.38651692170268
# Mean x: 120.40518798587843, Mean y: 23.385414150671533
# Saved to ./data/csv/飛行軌跡_20230826061336_R3871938722.csv
# Copied to ./data/飛行軌跡_20230826061336_R3871938722.csv
# Min x: 120.40463653147906, Min y: 23.386170249368885
# Max x: 120.40569233995267, Max y: 23.386460928993348
# Mean x: 120.40542390354973, Mean y: 23.386295313097367
# Saved to ./data/csv/飛行軌跡_20230812063907_R5872442435.csv
# Copied to ./data/飛行軌跡_20230812063907_R5872442435.csv
# Min x: 120.442385017981, Min y: 23.37117748272491
# Max x: 120.44413775053134, Max y: 23.37140049034185
# Mean x: 120.44279067891026, Mean y: 23.37129042101348
# Saved to ./data/csv/飛行軌跡_20230729081158_R1587787072.csv
# Copied to ./data/飛行軌跡_20230729081158_R1587787072.csv
# Min x: 120.44787492888268, Min y: 23.366163538931474
# Max x: 120.44838810044718, Max y: 23.3670882249824
# Mean x: 120.448061769827, Mean y: 23.36671734431757
# Saved to ./data/csv/飛行軌跡_20230907134723_R4230685181.csv
# Copied to ./data/飛行軌跡_20230907134723_R4230685181.csv
# Min x: 120.44990298319104, Min y: 23.374219476015455
# Max x: 120.45015963440474, Max y: 23.37542002109012
# Mean x: 120.45000768788304, Mean y: 23.374846778306175
# Saved to ./data/csv/飛行軌跡_20230930114151_R3619278177.csv
# Copied to ./data/飛行軌跡_20230930114151_R3619278177.csv
# Min x: 120.43924468693238, Min y: 23.38407654011069
# Max x: 120.43956272822093, Max y: 23.384113260428506
# Mean x: 120.43940370757666, Mean y: 23.3840949002696
# Saved to ./data/csv/飛行軌跡_20231023075047_R0731380022.csv
# Copied to ./data/飛行軌跡_20231023075047_R0731380022.csv
# Min x: 120.4072459228574, Min y: 23.394124697325534
# Max x: 120.40770365723442, Max y: 23.39540279833691
# Mean x: 120.40750148205332, Mean y: 23.394756263426235
# Saved to ./data/csv/飛行軌跡_20231017100635_R2309649346.csv
# Copied to ./data/飛行軌跡_20231017100635_R2309649346.csv
# Min x: 120.40195972522577, Min y: 23.371949010241327
# Max x: 120.40381092239059, Max y: 23.374804186895663
# Mean x: 120.40324633199668, Mean y: 23.372910653315785
# Saved to ./data/csv/飛行軌跡_20230914182007_R4603984674.csv
# Copied to ./data/飛行軌跡_20230914182007_R4603984674.csv
# Min x: 120.42295312308559, Min y: 23.39836148263435
# Max x: 120.42402769295416, Max y: 23.398553561192063
# Mean x: 120.42332755977337, Mean y: 23.39846600104251
# Saved to ./data/csv/飛行軌跡_20230812112019_R1977747692.csv
# Copied to ./data/飛行軌跡_20230812112019_R1977747692.csv
# Min x: 120.42458934035355, Min y: 23.369756740114635
# Max x: 120.42493843987333, Max y: 23.370727276637993
# Mean x: 120.42480508131814, Mean y: 23.370102850247527
# Saved to ./data/csv/飛行軌跡_20230915062239_R6963176279.csv
# Copied to ./data/飛行軌跡_20230915062239_R6963176279.csv
# Min x: 120.39909130271533, Min y: 23.39157708791312
# Max x: 120.39928140452679, Max y: 23.391731683553505
# Mean x: 120.39918245644567, Mean y: 23.391645043766985
# Saved to ./data/csv/飛行軌跡_20230915104342_R0935361564.csv
# Copied to ./data/飛行軌跡_20230915104342_R0935361564.csv
# Min x: 120.43101252066987, Min y: 23.426279457791846
# Max x: 120.43149329194534, Max y: 23.426528081377977
# Mean x: 120.43112531038093, Mean y: 23.42635399055403
# Saved to ./data/csv/飛行軌跡_20231031070940_R8395933885.csv
# Copied to ./data/飛行軌跡_20231031070940_R8395933885.csv
# Min x: 120.23280771212505, Min y: 23.2907777839037
# Max x: 120.23301237185412, Max y: 23.291126605883452
# Mean x: 120.23288322991979, Mean y: 23.29102753497755
# Saved to ./data/csv/飛行軌跡_20231116075839_R2913612386.csv
# Copied to ./data/飛行軌跡_20231116075839_R2913612386.csv
# Min x: 120.43009561479579, Min y: 23.36637412459551
# Max x: 120.43018003844246, Max y: 23.36741923204771
# Mean x: 120.43013575644497, Mean y: 23.36701514249807
# Saved to ./data/csv/飛行軌跡_20231103100143_R3317024692.csv
# Copied to ./data/飛行軌跡_20231103100143_R3317024692.csv
# Min x: 120.38846321261431, Min y: 23.37845927864714
# Max x: 120.38854685781098, Max y: 23.37927835273127
# Mean x: 120.38851092837393, Mean y: 23.37884561463904
# Saved to ./data/csv/飛行軌跡_20230722141939_R7389721172.csv
# Copied to ./data/飛行軌跡_20230722141939_R7389721172.csv
# Min x: 120.39373526266087, Min y: 23.39234278496062
# Max x: 120.3945799501796, Max y: 23.393348658239947
# Mean x: 120.39423486216236, Mean y: 23.392814074134986
# Saved to ./data/csv/飛行軌跡_20230802105032_R4205603392.csv
# Copied to ./data/飛行軌跡_20230802105032_R4205603392.csv
# Min x: 120.42647572445182, Min y: 23.4177465898545
# Max x: 120.42668219632064, Max y: 23.41878628711418
# Mean x: 120.4265523292012, Mean y: 23.418412452926926
# Saved to ./data/csv/飛行軌跡_20230721110621_R5955654373.csv
# Copied to ./data/飛行軌跡_20230721110621_R5955654373.csv
# Min x: 120.44379753529358, Min y: 23.365704975952664
# Max x: 120.4442403725146, Max y: 23.366866760114487
# Mean x: 120.44408380849846, Mean y: 23.366111442967874
# Saved to ./data/csv/飛行軌跡_20230824133527_R7461647480.csv
# Copied to ./data/飛行軌跡_20230824133527_R7461647480.csv
# Min x: 120.40074416756725, Min y: 23.390092162869113
# Max x: 120.40192880417607, Max y: 23.39167895350932
# Mean x: 120.40152703962916, Mean y: 23.390949335057098
# Saved to ./data/csv/飛行軌跡_20231020092008_R3365977908.csv
# Copied to ./data/飛行軌跡_20231020092008_R3365977908.csv
# Min x: 120.39844576388143, Min y: 23.374671882123646
# Max x: 120.39848131395262, Max y: 23.37556792130613
# Mean x: 120.39846440233447, Mean y: 23.37511384110843
# Saved to ./data/csv/飛行軌跡_20230716162833_R7176925222.csv
# Copied to ./data/飛行軌跡_20230716162833_R7176925222.csv
# Min x: 120.39653837634602, Min y: 23.392086480581334
# Max x: 120.39749624709023, Max y: 23.393016995588923
# Mean x: 120.3971435603965, Mean y: 23.392471144327658
# Saved to ./data/csv/飛行軌跡_20231027165016_R2143469653.csv
# Copied to ./data/飛行軌跡_20231027165016_R2143469653.csv
# Min x: 120.41238006294364, Min y: 23.341714842358076
# Max x: 120.41271243949645, Max y: 23.3423166676306
# Mean x: 120.41253762726413, Mean y: 23.342029183715383
# Saved to ./data/csv/飛行軌跡_20230906062043_R2418680118.csv
# Copied to ./data/飛行軌跡_20230906062043_R2418680118.csv
# Min x: 120.40471278783909, Min y: 23.350756142980643
# Max x: 120.40563828549722, Max y: 23.351585500416668
# Mean x: 120.40528050861958, Mean y: 23.351276694557914
# Saved to ./data/csv/飛行軌跡_20231019152317_R3383670408.csv
# Copied to ./data/飛行軌跡_20231019152317_R3383670408.csv
# Min x: 120.40391483716313, Min y: 23.382816562806102
# Max x: 120.40430905724233, Max y: 23.38378951181286
# Mean x: 120.4042246332004, Mean y: 23.383312956074835
# Saved to ./data/csv/飛行軌跡_20231029070833_R3020349449.csv
# Copied to ./data/飛行軌跡_20231029070833_R3020349449.csv
# Min x: 120.30412516595567, Min y: 23.346662679237692
# Max x: 120.30466486574319, Max y: 23.347567865989678
# Mean x: 120.30428217842511, Mean y: 23.34709237488047
# Saved to ./data/csv/飛行軌跡_20231109172121_R7634082668.csv
# Copied to ./data/飛行軌跡_20231109172121_R7634082668.csv
# Min x: 120.40032342597948, Min y: 23.374712441855863
# Max x: 120.40039692884648, Max y: 23.375609892317936
# Mean x: 120.40034985764669, Mean y: 23.375022442818977
# Saved to ./data/csv/飛行軌跡_20230805122337_R1066812808.csv
# Copied to ./data/飛行軌跡_20230805122337_R1066812808.csv
# Min x: 120.42318023925954, Min y: 23.376439685712366
# Max x: 120.4234616356473, Max y: 23.377460370087192
# Mean x: 120.42329628821213, Mean y: 23.376808312270434
# Saved to ./data/csv/飛行軌跡_20231104065813_R4457220233.csv
# Copied to ./data/飛行軌跡_20231104065813_R4457220233.csv
# Min x: 120.39926398678476, Min y: 23.374051691636996
# Max x: 120.39969012413157, Max y: 23.374622540542575
# Mean x: 120.39945039566521, Mean y: 23.374432107496393
# Saved to ./data/csv/飛行軌跡_20230812074725_R1470393903.csv
# Copied to ./data/飛行軌跡_20230812074725_R1470393903.csv
# Min x: 120.45042194110516, Min y: 23.376720554310314
# Max x: 120.45118055091089, Max y: 23.377583055442578
# Mean x: 120.45086065322361, Mean y: 23.37721893023899
# Saved to ./data/csv/飛行軌跡_20230925091400_R1924158104.csv
# Copied to ./data/飛行軌跡_20230925091400_R1924158104.csv
# Min x: 120.39724736178393, Min y: 23.39085424715492
# Max x: 120.39744451019395, Max y: 23.391959437422077
# Mean x: 120.397365998845, Mean y: 23.391563502287063
# Saved to ./data/csv/飛行軌跡_20230915152209_R6023975682.csv
# Copied to ./data/飛行軌跡_20230915152209_R6023975682.csv
# Min x: 120.3844830159787, Min y: 23.36493485395414
# Max x: 120.38601353090313, Max y: 23.36590043161475
# Mean x: 120.38568410235473, Mean y: 23.365287297204205
# Saved to ./data/csv/飛行軌跡_20230809163911_R2027156224.csv
# Copied to ./data/飛行軌跡_20230809163911_R2027156224.csv
# Min x: 120.42368487674634, Min y: 23.414179767909097
# Max x: 120.42420873737595, Max y: 23.414959786747126
# Mean x: 120.42391931233708, Mean y: 23.414562856677804
# Saved to ./data/csv/飛行軌跡_20230720130908_R8416183805.csv
# Copied to ./data/飛行軌跡_20230720130908_R8416183805.csv
# Min x: 120.38141966762339, Min y: 23.390504204772515
# Max x: 120.38175505134562, Max y: 23.392216448924973
# Mean x: 120.38161153256463, Mean y: 23.39137834088363
# Saved to ./data/csv/飛行軌跡_20230930080215_R7236282845.csv
# Copied to ./data/飛行軌跡_20230930080215_R7236282845.csv
# Min x: 120.39421338097456, Min y: 23.392358018926977
# Max x: 120.39432470554028, Max y: 23.3933031071549
# Mean x: 120.39426607410546, Mean y: 23.392712296982545
# Saved to ./data/csv/飛行軌跡_20230811102424_R5539541837.csv
# Copied to ./data/飛行軌跡_20230811102424_R5539541837.csv
# Min x: 120.40460817684418, Min y: 23.369984211979656
# Max x: 120.40577825574205, Max y: 23.370911319435614
# Mean x: 120.40557370717865, Mean y: 23.37050176384328
# Saved to ./data/csv/飛行軌跡_20230724113057_R4592117300.csv
# Copied to ./data/飛行軌跡_20230724113057_R4592117300.csv
# Min x: 120.39650547896264, Min y: 23.36310253967134
# Max x: 120.39748745132674, Max y: 23.363636939024758
# Mean x: 120.39718357731273, Mean y: 23.363372208744554
# Saved to ./data/csv/飛行軌跡_20231017093011_R5385315716.csv
# Copied to ./data/飛行軌跡_20231017093011_R5385315716.csv
# Min x: 120.34450313390033, Min y: 23.350227190840194
# Max x: 120.34483511769751, Max y: 23.351112620130106
# Mean x: 120.34465059653931, Mean y: 23.35068324255931
# Saved to ./data/csv/飛行軌跡_20231024075802_R2092257573.csv
# Copied to ./data/飛行軌跡_20231024075802_R2092257573.csv
# Min x: 120.40205500006051, Min y: 23.374753715546376
# Max x: 120.4026775274226, Max y: 23.375618673183155
# Mean x: 120.40250285173663, Mean y: 23.37517575977762
# Saved to ./data/csv/飛行軌跡_20230808175411_R2670986560.csv
# Copied to ./data/飛行軌跡_20230808175411_R2670986560.csv
# Min x: 120.42079082289892, Min y: 23.41581348779071
# Max x: 120.42162081440937, Max y: 23.41596222699933
# Mean x: 120.4212233902541, Mean y: 23.41591257237694
# Saved to ./data/csv/飛行軌跡_20230824083332_R6722832435.csv
# Copied to ./data/飛行軌跡_20230824083332_R6722832435.csv
# Min x: 120.4529622423072, Min y: 23.372295903464103
# Max x: 120.45341981547313, Max y: 23.373318872702185
# Mean x: 120.4531934451311, Mean y: 23.37276379482039
# Saved to ./data/csv/飛行軌跡_20231029102543_R5834706954.csv
# Copied to ./data/飛行軌跡_20231029102543_R5834706954.csv
# Min x: 120.40211233510986, Min y: 23.374756459331184
# Max x: 120.40293598120866, Max y: 23.375654145624313
# Mean x: 120.40249935133723, Mean y: 23.37511359448177
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 167
#     164 kml_pathes = [f"./data/raw_kml/{kml_path}" for kml_path in kml_pathes]
#     166 for kml_path in kml_pathes:
# --> 167     convert_kml_to_csv(kml_path)
#
# Cell In[2], line 137, in convert_kml_to_csv(kml_path)
#     133 base_timestamp = "2008-12-11 04:42:14+00"
#     135 csv_file_path = f"./data/csv/{kml_name}.csv"
# --> 137 write_to_csv(
#     138     csv_file_path,
#     139     coordinates,
#     140     trajectory_id,
#     141     tracker,
#     142     base_timestamp,
#     143     mean_x,
#     144     mean_y,
#     145     grid_size_half,
#     146     xy_n=xy_n,
#     147 )
#     148 # shutil.copy(csv_file_path, os.path.expanduser("./data/"))
#     149 print(f"Copied to ./data/{kml_name}.csv")
#
# Cell In[2], line 110, in write_to_csv(csv_file_path, coordinates, trajectory_id, tracker, base_timestamp, mean_x, mean_y, grid_size_half, xy_n)
#     108 for i, coord in enumerate(path, start=len(coordinates) + 1):
#     109     x, y = coord
# --> 110     timestamp = (base_time + timedelta(seconds=1 * (i - 1))).isoformat()
#     111     row = [x, y, i, i, i, trajectory_id + 1, tracker, timestamp]
#     112     writer.writerow(row)
#
# KeyboardInterrupt:

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine_distance(lat1, lon1, lat2, lon2):
    
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = 6371 * c # Radius of earth in kilometers

    return distance

# %%
def calculate_total_distance(file_path):
    total_distance = 0
    with open(file_path, 'r') as file:
        reader = csv.reader(file, delimiter=';')
        headers = next(reader)  # Skip header
        prev_lat, prev_lon = None, None
        for row in reader:
            if row[5] == '1':
                lat, lon = map(float, row[:2])  # Assuming latitude is in first column, longitude in second
                if prev_lat is not None and prev_lon is not None:
                    total_distance += haversine_distance(prev_lat, prev_lon, lat, lon)
                prev_lat, prev_lon = lat, lon
    return total_distance

# %%
file_path = "./data/飛行軌跡_20230716070634_R8039938565.csv"
total_distance = calculate_total_distance(file_path)*1000
print(f"Total distance: {total_distance:} m")
# Out:
# Total distance: 47.171501281335544 m

# %%
directory_path = "./data/csv"
file_extension = ".csv"  

# find all csv files in the directory
csv_pathes = get_specific_filenames(directory_path, file_extension)
#output_file = "./data/test.csv"
output_file = "./data/distances.csv"

with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=';')
    # write header
    writer.writerow(['csv_path', 'total_distance(m)'])
    
    # calculate total distance for each csv file
    for csv_path in csv_pathes:
        file_path = os.path.join(directory_path, csv_path)
        total_distance = calculate_total_distance(file_path)*1000
        # write to csv
        writer.writerow([csv_path, total_distance])

print("Distances saved to", output_file)
# Out:
# Distances saved to ./data/distances.csv

# %% [markdown]
# ![alt text](./img/distance.png)
